// %%
import $ivy.`org.apache.spark::spark-sql:4.1.1`
// Out:
// import $ivy.$

// %%
val version = scala.io.Source.fromFile("../VERSION")  // Get version from file
  .getLines().next().trim

interp.load.ivy("org.dataprov.dp" %% "dp-spark" % version)  // use porogrammatic API 

// // For publishLocal (~/.ivy2/local)
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method

// // For publishM2 (~/.m2)
// import $repo.`file:///home/ronan/.m2/repository`
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method
// Out:
// version: String = "0.0.1"

// %%
import java.sql.Date

import org.apache.spark.sql.{SparkSession, DataFrame}
import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
import org.apache.spark.sql.execution.SparkPlan
import org.apache.spark.sql.functions._

import org.dataprov.dp.wringlet.ProvenanceApi._
import org.dataprov.dp.wringlet.LogicalPlanWithProvenance
import org.dataprov.dp.wringlet.SparkProvenanceExtension
import org.dataprov.dp.wringlet.FullWhyProvenanceBuilder
import org.dataprov.dp.wringlet.SemiWhyProvenanceBuilder
// Out:
// import java.sql.Date
// import org.apache.spark.sql.{SparkSession, DataFrame}
// import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
// import org.apache.spark.sql.execution.SparkPlan
// import org.apache.spark.sql.functions._
// import org.dataprov.dp.wringlet.ProvenanceApi._
// import org.dataprov.dp.wringlet.LogicalPlanWithProvenance
// import org.dataprov.dp.wringlet.SparkProvenanceExtension
// import org.dataprov.dp.wringlet.FullWhyProvenanceBuilder
// import org.dataprov.dp.wringlet.SemiWhyProvenanceBuilder

// %%
import org.apache.spark.sql.SparkSession

val sparkWhy = SparkSession.builder()
    .appName("notebook-demo-why-provenance")
    .master("local[*]")
    .withExtensions(
        new SparkProvenanceExtension(
            provenanceBuilder = SemiWhyProvenanceBuilder
        )
    )
    .config("spark.provenance.enabled", "true")
    .getOrCreate()

println(s"Spark provenance enabled: ${sparkWhy.conf.get("spark.provenance.enabled")}")
sparkWhy.sparkContext.setLogLevel("ERROR")
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
// 26/07/27 10:53:31 INFO SparkContext: Running Spark version 4.1.1
// 26/07/27 10:53:31 INFO SparkContext: OS info Mac OS X, 26.5, aarch64
// 26/07/27 10:53:31 INFO SparkContext: Java version 17.0.10+7
// 26/07/27 10:53:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 26/07/27 10:53:32 INFO ResourceUtils: ==============================================================
// 26/07/27 10:53:32 INFO ResourceUtils: No custom resources configured for spark.driver.
// 26/07/27 10:53:32 INFO ResourceUtils: ==============================================================
// 26/07/27 10:53:32 INFO SparkContext: Submitted application: notebook-demo-why-provenance
// 26/07/27 10:53:32 INFO SecurityManager: Changing view acls to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing modify acls to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing view acls groups to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing modify acls groups to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: mac-ABALLA16 groups with view permissions: EMPTY; users with modify permissions: mac-ABALLA16; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/07/27 10:53:32 INFO Utils: Successfully started service 'sparkDriver' on port 52477.
// 26/07/27 10:53:32 INFO SparkEnv: Registering MapOutputTracker
// 26/07/27 10:53:32 INFO SparkEnv: Registering BlockManagerMaster
// 26/07/27 10:53:32 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 26/07/27 10:53:32 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 26/07/27 10:53:32 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
// 26/07/27 10:53:32 INFO DiskBlockManager: Created local directory at /private/var/folders/6z/k8ghthcd26d8l7x7_h01rn4h0000gp/T/blockmgr-50c6427b-023b-49df-a707-1fc64ac8852b
// 26/07/27 10:53:32 INFO SparkEnv: Registering OutputCommitCoordinator
// 26/07/27 10:53:32 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
// 26/07/27 10:53:32 INFO Utils: Successfully started service 'SparkUI' on port 4040.
// 26/07/27 10:53:32 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
// 26/07/27 10:53:32 INFO ResourceProfile: Limiting resource is cpu
// 26/07/27 10:53:32 INFO ResourceProfileManager: Added ResourceProfile id: 0
// 26/07/27 10:53:32 INFO SecurityManager: Changing view acls to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing modify acls to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing view acls groups to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: Changing modify acls groups to: mac-ABALLA16
// 26/07/27 10:53:32 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: mac-ABALLA16 groups with view permissions: EMPTY; users with modify permissions: mac-ABALLA16; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/07/27 10:53:32 INFO Executor: Starting executor ID driver on host 10.31.153.139
// 26/07/27 10:53:32 INFO Executor: OS info Mac OS X, 26.5, aarch64
// 26/07/27 10:53:32 INFO Executor: Java version 17.0.10+7
// 26/07/27 10:53:32 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
// 26/07/27 10:53:32 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@5a141644 for default.
// 26/07/27 10:53:32 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 52478.
// 26/07/27 10:53:32 INFO NettyBlockTransferService: Server created on 10.31.153.139:52478
// 26/07/27 10:53:32 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 26/07/27 10:53:32 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.31.153.139, 52478, None)
// 26/07/27 10:53:32 INFO BlockManagerMasterEndpoint: Registering block manager 10.31.153.139:52478 with 2.2 GiB RAM, BlockManagerId(driver, 10.31.153.139, 52478, None)
// 26/07/27 10:53:32 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.31.153.139, 52478, None)
// 26/07/27 10:53:32 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.31.153.139, 52478, None)
// 26/07/27 10:53:32 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
// 26/07/27 10:53:32 INFO SharedState: Warehouse path is 'file:/Users/mac-ABALLA16/spark-data-provenance/scala-spark-data-provenance/notebooks/spark-warehouse'.
// Spark provenance enabled: true
// import org.apache.spark.sql.SparkSession
// sparkWhy: SparkSession = org.apache.spark.sql.classic.SparkSession@b2e77a0

// %%
// Example of loading a Parquet file and adding provenance

val localPath = "file:///Users/mac-ABALLA16/Downloads/product_hierarchy"
val df = sparkWhy.read.format("parquet").load(localPath)

println(s"Nombre de lignes réelles chargées : ${df.count()}")

val dfWithProv = df.addProvenanceColumn
dfWithProv.show(20, false)
// Out:
// Nombre de lignes réelles chargées : 55526486
// +----------+-----------+---------------------------+-------------------+------------------------------------+---------------+-----------------------+-------------+-----------------------------------+--------------+-------------------+-----------------+---------------------------+------------------------------------+
// |model_code|family_code|family_name                |sub_department_code|sub_department_name                 |department_code|department_name        |universe_code|universe_name                      |hierarchy_type|validity_start_date|validity_end_date|tech_ingestion_datetime_utc|_provenance_tag                     |
// +----------+-----------+---------------------------+-------------------+------------------------------------+---------------+-----------------------+-------------+-----------------------------------+--------------+-------------------+-----------------+---------------------------+------------------------------------+
// |1         |5053       |UNDERWEAR TEAM SPORT SENIOR|1970               |TEAMSPORT THERMICAL APPAREL         |902            |Football/soccer        |10           |Football univ                      |RETAIL        |2017-02-12         |2018-01-27       |2025-12-11 15:39:35.313706 |ac86b0c4-7317-4bf0-aae9-afd7ae90c890|
// |2         |5053       |UNDERWEAR TEAM SPORT SENIOR|137                |MAN FOOTBALL                        |902            |SOCCER / FUTSAL / SEPAK|10           |TEAMSPORTS UNIVERS                 |RETAIL        |2021-08-29         |2023-01-28       |2025-12-11 15:39:35.313706 |1a3c16e5-c35c-4b4a-87b2-a4b9309acaec|
// |2         |5053       |UNDERWEAR TEAM SPORT SENIOR|137                |MEN FOOTBALL                        |902            |FOOTBALL & FUTSAL      |10           |TEAMSPORTS                         |DMI           |2024-08-25         |2024-09-07       |2025-12-11 15:39:35.313706 |f197a0e4-ac6f-4e5b-a4cb-3a3c006e3486|
// |2         |5053       |UNDERWEAR TEAM SPORT SENIOR|1967               |Training and accessories            |902            |Football / Soccer      |10           |Teamsports                         |DMI           |2016-02-14         |2017-02-11       |2025-12-11 15:39:35.313706 |32aacce5-1148-414d-88c0-8088346e188a|
// |4         |5053       |Ad foot underwear          |137                |Adult football                      |902            |Football / Soccer      |10           |Teamsports                         |DMI           |2009-01-04         |2011-02-05       |2025-12-11 15:39:35.313706 |7746fbb9-85c9-472e-9897-bae69acc6d6f|
// |4         |5053       |UNDERWEAR TEAM SPORT SENIOR|1827               |Training and accessories            |902            |Football/soccer        |10           |Teamsports                         |RETAIL        |2016-02-14         |2017-02-11       |2025-12-11 15:39:35.313706 |9c4f2231-6f24-444c-9867-1ff72bd83765|
// |11        |11966      |CONNECTED WATCHES          |2851               |SPORTS ELECTRONICS                  |684            |SPORTS ACCESSORIES     |32           |HEALTH & SPORTS ACCESSORIES        |DMI           |2025-01-26         |9999-12-25       |2025-12-11 15:39:35.313706 |b676ca31-1676-47f7-bedd-9a1d1b671ddd|
// |11        |11966      |CONNECTED WATCHES          |2994               |SPORTS ELECTRONICS                  |620            |SPORTS ACCESSORIES     |9            |UNIVERS HEALTH & SPORTS ACCESSORIES|RETAIL        |2025-01-26         |9999-12-25       |2025-12-11 15:39:35.313706 |c91600fe-ab0c-40e9-80f6-c2b6eb19ab33|
// |11        |11966      |GPS WATCHES                |9000               |Progress and Performance            |131            |Electronics            |9            |Health Discovery univ              |RETAIL        |2017-02-12         |2017-07-08       |2025-12-11 15:39:35.313706 |d6828fdd-63b7-4420-965a-ab5a94b795eb|
// |11        |11966      |RUNNING GPS WATCHES        |2235               |Road Running Complementary Equipment|128            |Road running           |9002         |Road running Univ                  |RETAIL        |2018-05-27         |2019-01-19       |2025-12-11 15:39:35.313706 |551703e9-237a-490f-b86e-00231596900c|
// |12        |5053       |Ad foot underwear          |137                |Adult's football                    |902            |Football / Soccer      |10           |Teamsports                         |DMI           |2008-12-28         |2009-01-03       |2025-12-11 15:39:35.313706 |fd817bf8-9d82-4b6c-8891-6f1c0d0663cd|
// |12        |5053       |UNDERWEAR TEAM SPORT ADULT |137                |FOOTBALL ADULTE                     |902            |FOOTBALL & FUTSAL      |10           |TEAMSPORTS                         |DMI           |2024-09-08         |2026-01-24       |2025-12-11 15:39:35.313706 |9c2df796-4f4e-4589-a1ac-41f766e0d974|
// |12        |5053       |UNDERWEAR TEAM SPORT SENIOR|2126               |TEAMSPORTS THERMO DRY APPAREL       |902            |Football / Soccer 11   |10           |Football                           |DMI           |2017-11-12         |2018-01-27       |2025-12-11 15:39:35.313706 |17afcef1-4dc2-4ab8-be20-49d7bc510dfc|
// |13        |5053       |Ad foot underwear          |137                |Adult Football                      |902            |Football/soccer        |10           |Teamsports                         |RETAIL        |2008-12-28         |2010-02-20       |2025-12-11 15:39:35.313706 |25cd217e-95ca-4907-9255-d70cae6cc862|
// |13        |5053       |Ad foot underwear          |137                |Adult Football                      |902            |Football/soccer        |10           |Teamsports                         |RETAIL        |2010-02-21         |2011-02-05       |2025-12-11 15:39:35.313706 |1929c400-184c-4769-9dcb-6409355e8b80|
// |13        |5053       |UNDERWEAR TEAM SPORT ADULT |137                |FOOTBALL ADULTE                     |902            |FOOTBALL & FUTSAL      |10           |TEAMSPORTS                         |DMI           |2024-09-08         |2026-01-24       |2025-12-11 15:39:35.313706 |fdaab1bf-5356-4e98-80f5-8330024e0396|
// |14        |5053       |Ad foot underwear          |137                |Adult Football                      |902            |Football/soccer        |10           |Teamsports                         |RETAIL        |2008-12-28         |2010-02-20       |2025-12-11 15:39:35.313706 |7d90354a-dfee-455b-af5a-1c8267ce799b|
// |14        |5053       |Ad foot underwear          |137                |Adult Football                      |902            |Football/soccer        |10           |Teamsports                         |RETAIL        |2010-02-21         |2011-02-05       |2025-12-11 15:39:35.313706 |f9369405-7e7c-4865-b88b-f83903976b39|
// |14        |5053       |M football underwear       |137                |Men's football equip and balls      |902            |Football / Soccer      |10           |Teamsports                         |DMI           |1900-01-01         |2008-12-27       |2025-12-11 15:39:35.313706 |1c08c633-a246-42af-b88d-9d7ab957d751|
// |14        |5053       |UNDERWEAR TEAM SPORT SENIOR|1967               |Training and accessories            |902            |Football / Soccer      |10           |Teamsports                         |DMI           |2016-02-14         |2017-02-11       |2025-12-11 15:39:35.313706 |ec086c3d-63ac-40dd-a9c0-79a6583d4e49|
// +----------+-----------+---------------------------+-------------------+------------------------------------+---------------+-----------------------+-------------+-----------------------------------+--------------+-------------------+-----------------+---------------------------+------------------------------------+
// only showing top 20 rows
// localPath: String = "file:///Users/mac-ABALLA16/Downloads/product_hierarchy"
// df: DataFrame = [model_code: bigint, family_code: bigint ... 11 more fields]
// dfWithProv: DataFrame = [model_code: bigint, family_code: bigint ... 12 more fields]

// %%
def complexPipeline(df: DataFrame): DataFrame = {
  
  val baseDF = df
    .filter(col("model_code").isNotNull && col("validity_start_date").isNotNull)
    .withColumn("start_dt", to_date(col("validity_start_date"), "yyyy-MM-dd"))
    .withColumn("end_dt", to_date(col("validity_end_date"), "yyyy-MM-dd"))
    .select("model_code", "hierarchy_type", "family_code", "family_name", "start_dt", "end_dt")
    .distinct()

  val rankedDF = baseDF.as("r1")
    .join(
      baseDF.as("r2"),
      expr("""
        r1.model_code = r2.model_code 
        AND r1.hierarchy_type = r2.hierarchy_type 
        AND r1.start_dt > r2.start_dt
      """),
      "left"
    )
    .groupBy("r1.model_code", "r1.hierarchy_type", "r1.family_code", "r1.family_name", "r1.start_dt", "r1.end_dt")
    .agg(count("r2.start_dt").as("row_rank")) 

  val anomaliesDF = rankedDF.filter(col("end_dt") >= col("start_dt"))

  val finalDF = anomaliesDF
    .groupBy("family_code", "family_name")
    .agg(countDistinct("model_code").as("nb_modeles_en_conflit"))
    .orderBy(desc("nb_modeles_en_conflit"))

  finalDF
}

val dfResult = complexPipeline(df)
dfResult.show(10, false)
// Out:
// +-----------+--------------------------------------+---------------------+
// |family_code|family_name                           |nb_modeles_en_conflit|
// +-----------+--------------------------------------+---------------------+
// |11957      |MAN ESSENTIALS T-SHIRT & TANK         |14272                |
// |11957      |MAN T-SHIRT & TANK ESSENTIALS         |14223                |
// |11957      |MAN GYM, PILATES APPAREL              |14173                |
// |11957      |MAN FIT ACTIVE LIGHT MAN TS SHORT TANK|14172                |
// |11957      |MAN PILATES, SOFT GYM APPAREL         |14127                |
// |11957      |MAN T SHIRT SHORT                     |14121                |
// |11957      |MAN T-SHIRT & SHORT DAILY             |13830                |
// |10789      |WOMAN CARDIO & STRENGTH               |13044                |
// |10789      |WOMAN CARDIO & STRENGTH PERF          |12738                |
// |11956      |WOMAN T SHIRT LEGGING SHORT           |12578                |
// +-----------+--------------------------------------+---------------------+
// only showing top 10 rows
// defined function complexPipeline
// dfResult: DataFrame = [family_code: bigint, family_name: string ... 1 more field]

// %%
val aggregate = dfWithProv.select("model_code", "family_name", "department_name","sub_department_name").groupBy("sub_department_name", "model_code").agg(count("*").as("count"))
//aggregate.show(10,false)

val finalRows = aggregate.filter(col("model_code") === "1037865" || col("model_code") === "1127317").select("_provenance_tag")
//finalRows.show(20, false)

//sparkWhy.conf.set("spark.provenance.enabled", "false")

withProvenanceDisabled(sparkWhy) {
  val finalTags = finalRows
    .select(explode((col("_provenance_tag"))).as("_provenance_tag"))
    .distinct()

   val initialRows = dfWithProv
    .join(finalTags, Seq("_provenance_tag"), "left_semi")

   initialRows.filter(col("sub_department_code") === 1962).show(20, false)
}
// Out:
// +------------------------------------+----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// |_provenance_tag                     |model_code|family_code|family_name       |sub_department_code|sub_department_name |department_code|department_name            |universe_code|universe_name             |hierarchy_type|validity_start_date|validity_end_date|tech_ingestion_datetime_utc|
// +------------------------------------+----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// |005e5e03-1925-4801-8a41-81c02c5dc8ae|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2025-12-11 15:39:35.313706 |
// |629db762-e718-4a12-ba4b-6e0310590c04|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2025-12-11 15:39:35.313706 |
// |9cbcebb4-b62c-4ec5-a573-639433562d6c|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2025-12-11 15:39:35.313706 |
// |8cefba69-8fc9-42f6-bf90-ed273c4a5339|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2026-04-20 16:27:08.803121 |
// |59c8c053-25e4-4c54-96b9-053a1ee288a7|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2026-04-20 16:27:08.803121 |
// |e1c68aac-d12b-4f7f-ae1c-15fadda8a147|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2026-04-20 16:27:08.803121 |
// |e29852a7-9497-4aaa-8c87-ff2c2445dd08|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2026-04-21 07:26:18.88928  |
// |8e5880ee-47cc-4235-93de-531e576bf181|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2026-04-21 07:26:18.88928  |
// |61372f9d-9fc3-40a8-92ca-e1db3d59ec73|1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2026-04-21 07:26:18.88928  |
// +------------------------------------+----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// aggregate: DataFrame = [sub_department_name: string, model_code: bigint ... 2 more fields]
// finalRows: DataFrame = [_provenance_tag: array<string>]

// %%
import org.dataprov.dp.wringlet._ 

val rowsToDebug = aggregate.filter(col("model_code") === "1037865" || col("model_code") === "1127317")
withProvenanceDisabled(sparkWhy) {
  val Seq(initialRowsFromFramework) = rowsToDebug.getMinimalSources(Seq(dfWithProv))
  initialRowsFromFramework.filter(col("sub_department_code") === 1962).show(20, false)
}
// Out:
// +----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// |model_code|family_code|family_name       |sub_department_code|sub_department_name |department_code|department_name            |universe_code|universe_name             |hierarchy_type|validity_start_date|validity_end_date|tech_ingestion_datetime_utc|
// +----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2025-12-11 15:39:35.313706 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2025-12-11 15:39:35.313706 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2025-12-11 15:39:35.313706 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2026-04-20 16:27:08.803121 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2026-04-20 16:27:08.803121 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2026-04-20 16:27:08.803121 |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |BIG GAME AMMUNITIONS|471            |BIG GAME HUNTING           |7            |HUNTING AND SHOOTING SPORT|RETAIL        |2019-01-20         |2021-01-30       |2026-04-21 07:26:18.88928  |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|471            |BIG GAME HUNTING           |7            |Hunting univ              |RETAIL        |2018-01-28         |2019-01-19       |2026-04-21 07:26:18.88928  |
// |1127317   |10870      |RIFFLE AMMUNITIONS|1962               |Big game ammunitions|13             |WILDLIFE WATCHING / HUNTING|7            |Hunting univ              |RETAIL        |2017-02-12         |2018-01-27       |2026-04-21 07:26:18.88928  |
// +----------+-----------+------------------+-------------------+--------------------+---------------+---------------------------+-------------+--------------------------+--------------+-------------------+-----------------+---------------------------+
// import org.dataprov.dp.wringlet._
// rowsToDebug: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [sub_department_name: string, model_code: bigint ... 2 more fields]

// %%
val distinct = dfWithProv.select("family_name").distinct()
distinct.show(false)
// Out:
// +--------------------------------------+--------------------------------------+
// |family_name                           |_provenance_tag                       |
// +--------------------------------------+--------------------------------------+
// |'PULL-APART' POLE FISHING RODS, ACCESS|[2ccee26b-56ba-4868-aecd-a667e80b21fb]|
// |(!) EMPTY EXPO BACKBOARDS             |[56e81abd-b04e-4f6b-8da5-6717284039ce]|
// |(!) EXPO BACKBOARDS                   |[abee131b-73d3-487e-a689-b1e61b28c709]|
// |0L Replica                            |[09200480-c040-423a-8c05-2597788455e9]|
// |10L TO 30L NATURE HIKING BACKPACKS    |[9ec5b7ff-dd2a-4ba9-a7ea-167a23a22f6d]|
// |11 FOOTBALL BALLS                     |[e92ed420-a883-484a-b395-0e0d529612da]|
// |12"/14" Bikes (3-5 years)             |[2369d405-6079-4c3c-8706-05658639926b]|
// |16 INCHES BIKES (4-6 YEARS)           |[f800b953-8092-4c09-b14b-fe8178c733be]|
// |16I                                   |[d7d82f03-6839-4d15-aa74-59934f2a7c34]|
// |20 GA CARTRIDGES/SLUGS                |[34618340-f7a4-4df7-b035-3e0392643ed2]|
// |20 INCHES BIKES                       |[ff614019-3a48-46e8-b9b5-544a132b96a6]|
// |2ND LIFE TEXTILE TRAINING DO NOT USE  |[a5ce21e0-2535-4e30-9cb5-52ba116006d3]|
// |ACADEMIC ACCESSORIES                  |[b68e862b-5a86-4fdd-9498-389d33becdb4]|
// |ACADEMIC BLADES & RUBBERS             |[c69324ce-67b9-42a4-9ee4-dcceadf2d658]|
// |ACADEMIC BOARD                        |[0146ff9b-9b28-4320-aade-1a0c62cb7218]|
// |ACADEMIC RACKETS ACCESORIES           |[cf9ef648-55a0-4d44-bcd1-67f4e4ceb730]|
// |ACCESORIES FREESTYLE SCOOTER          |[c2e92d94-c89c-455d-a238-643e9e214298]|
// |ACCESSORIE BACKPACK SAFETY HIKING     |[4fe94771-e398-4ae8-b980-2807b03afbff]|
// |ACCESSORIES                           |[34ae213e-63c7-443a-9352-deee6677db85]|
// |ACCESSORIES CITY                      |[02053017-5847-407b-862e-bb0c5442239e]|
// +--------------------------------------+--------------------------------------+
// only showing top 20 rows
// distinct: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [family_name: string, _provenance_tag: array<string>]
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
