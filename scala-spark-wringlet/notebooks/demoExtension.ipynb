// %% [markdown]
// ## Demonstration: Using the Provenance Extension
//
// **Prerequisite to run this notebook:** having [almond jupyter plugin](https://almond.sh/) installed, and running cells using a Scala kernel
//
// To use Spark, we can use `$ivy` magic: https://almond.sh/docs/usage-spark

// %%
import $ivy.`org.apache.spark::spark-sql:4.1.1`
// Out:
// import $ivy.$

// %% [markdown]
// We can also use `ivy` to load project source code from local Ivy/Maven cache (run `make publish-local` to update):

// %%
val version = scala.io.Source.fromFile("../VERSION")  // Get version from file
  .getLines().next().trim

interp.load.ivy("org.dataprov.dp" %% "dp-spark" % version)  // use porogrammatic API 

// // For publishLocal (~/.ivy2/local)
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method

// // For publishM2 (~/.m2)
// import $repo.`file:///home/ronan/.m2/repository`
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method
// Out:
// version: String = "0.0.1"

// %% [markdown]
// Import libraries (Spark, dataprovenance project, ...):

// %%
import java.sql.Date

import org.apache.spark.sql.{SparkSession, DataFrame}
import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
import org.apache.spark.sql.execution.SparkPlan
import org.apache.spark.sql.functions._
import org.apache.spark.sql.expressions.Window._
import org.apache.spark.sql.expressions.WindowSpec

import org.dataprov.dp.wringlet.ProvenanceApi._
import org.dataprov.dp.wringlet.LogicalPlanWithProvenance
import org.dataprov.dp.wringlet.SparkProvenanceExtension
import org.dataprov.dp.wringlet.SemiWhyProvenanceBuilder
import org.dataprov.dp.wringlet.FullWhyProvenanceBuilder
import org.dataprov.dp.wringlet.DisplayStringProvenanceBuilder
// Out:
// import java.sql.Date
// import org.apache.spark.sql.{SparkSession, DataFrame}
// import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
// import org.apache.spark.sql.execution.SparkPlan
// import org.apache.spark.sql.functions._
// import org.apache.spark.sql.expressions.Window._
// import org.apache.spark.sql.expressions.WindowSpec
// import org.dataprov.dp.wringlet.ProvenanceApi._
// import org.dataprov.dp.wringlet.LogicalPlanWithProvenance
// import org.dataprov.dp.wringlet.SparkProvenanceExtension
// import org.dataprov.dp.wringlet.SemiWhyProvenanceBuilder
// import org.dataprov.dp.wringlet.FullWhyProvenanceBuilder
// import org.dataprov.dp.wringlet.DisplayStringProvenanceBuilder

// %% [markdown]
// The SemiWhyProvenanceBuilder is a simple implementation of the ProvenanceBuilder trait that captures
// the logical plan and physical plan for each transformation.
//
// It can be used to track the lineage of data through the transformations and understand how the final result was derived from the input data.
//
// ## Initialize Spark session:
// - The provenance builder can be customized to use different provenance models (e.g. SemiWhyProvenanceBuilder) the default is DisplayStringProvenanceBuilder
// - A new provenance builder can be created directly by overriding the operations (e.g. provType, single, join, distinct, aggregate)
// - The name of the provenance column can also be customized the default is "_provenance_tag"

// %%
import org.apache.spark.sql.SparkSession

val sparkWhy = SparkSession.builder()
    .appName("notebook-demo-why-provenance")
    .master("local[*]")
    // Vos extensions de provenance
    .withExtensions(
        new SparkProvenanceExtension(provenanceBuilder = SemiWhyProvenanceBuilder)
    )
    .config("spark.provenance.enabled", "true")
    .getOrCreate()

println(s"Spark provenance enabled: ${sparkWhy.conf.get("spark.provenance.enabled")}")
sparkWhy.sparkContext.setLogLevel("ERROR")
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
// 26/07/20 10:59:44 INFO SparkContext: Running Spark version 4.1.1
// 26/07/20 10:59:44 INFO SparkContext: OS info Mac OS X, 26.4.1, aarch64
// 26/07/20 10:59:44 INFO SparkContext: Java version 17.0.10+7
// 26/07/20 10:59:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 26/07/20 10:59:44 INFO ResourceUtils: ==============================================================
// 26/07/20 10:59:44 INFO ResourceUtils: No custom resources configured for spark.driver.
// 26/07/20 10:59:44 INFO ResourceUtils: ==============================================================
// 26/07/20 10:59:44 INFO SparkContext: Submitted application: notebook-demo-why-provenance
// 26/07/20 10:59:44 INFO SecurityManager: Changing view acls to: mac-ABALLA16
// 26/07/20 10:59:44 INFO SecurityManager: Changing modify acls to: mac-ABALLA16
// 26/07/20 10:59:44 INFO SecurityManager: Changing view acls groups to: mac-ABALLA16
// 26/07/20 10:59:44 INFO SecurityManager: Changing modify acls groups to: mac-ABALLA16
// 26/07/20 10:59:44 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: mac-ABALLA16 groups with view permissions: EMPTY; users with modify permissions: mac-ABALLA16; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/07/20 10:59:45 INFO Utils: Successfully started service 'sparkDriver' on port 58919.
// 26/07/20 10:59:45 INFO SparkEnv: Registering MapOutputTracker
// 26/07/20 10:59:45 INFO SparkEnv: Registering BlockManagerMaster
// 26/07/20 10:59:45 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 26/07/20 10:59:45 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 26/07/20 10:59:45 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
// 26/07/20 10:59:45 INFO DiskBlockManager: Created local directory at /private/var/folders/6z/k8ghthcd26d8l7x7_h01rn4h0000gp/T/blockmgr-4a820361-c4af-46fd-8900-e4eab472b0f0
// 26/07/20 10:59:45 INFO SparkEnv: Registering OutputCommitCoordinator
// 26/07/20 10:59:45 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
// 26/07/20 10:59:45 INFO Utils: Successfully started service 'SparkUI' on port 4040.
// 26/07/20 10:59:45 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
// 26/07/20 10:59:45 INFO ResourceProfile: Limiting resource is cpu
// 26/07/20 10:59:45 INFO ResourceProfileManager: Added ResourceProfile id: 0
// 26/07/20 10:59:45 INFO SecurityManager: Changing view acls to: mac-ABALLA16
// 26/07/20 10:59:45 INFO SecurityManager: Changing modify acls to: mac-ABALLA16
// 26/07/20 10:59:45 INFO SecurityManager: Changing view acls groups to: mac-ABALLA16
// 26/07/20 10:59:45 INFO SecurityManager: Changing modify acls groups to: mac-ABALLA16
// 26/07/20 10:59:45 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: mac-ABALLA16 groups with view permissions: EMPTY; users with modify permissions: mac-ABALLA16; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/07/20 10:59:45 INFO Executor: Starting executor ID driver on host 10.31.153.186
// 26/07/20 10:59:45 INFO Executor: OS info Mac OS X, 26.4.1, aarch64
// 26/07/20 10:59:45 INFO Executor: Java version 17.0.10+7
// 26/07/20 10:59:45 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
// 26/07/20 10:59:45 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@772d5f2d for default.
// 26/07/20 10:59:45 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 58920.
// 26/07/20 10:59:45 INFO NettyBlockTransferService: Server created on 10.31.153.186:58920
// 26/07/20 10:59:45 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 26/07/20 10:59:45 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.31.153.186, 58920, None)
// 26/07/20 10:59:45 INFO BlockManagerMasterEndpoint: Registering block manager 10.31.153.186:58920 with 2.2 GiB RAM, BlockManagerId(driver, 10.31.153.186, 58920, None)
// 26/07/20 10:59:45 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.31.153.186, 58920, None)
// 26/07/20 10:59:45 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.31.153.186, 58920, None)
// 26/07/20 10:59:46 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
// 26/07/20 10:59:46 INFO SharedState: Warehouse path is 'file:/Users/mac-ABALLA16/spark-data-provenance/scala-spark-data-provenance/notebooks/spark-warehouse'.
// Spark provenance enabled: true
// import org.apache.spark.sql.SparkSession
// sparkWhy: SparkSession = org.apache.spark.sql.classic.SparkSession@2572b4af

// %% [markdown]
// Create Spark dataframe:

// %%
val df: DataFrame = sparkWhy.createDataFrame(
    Seq(
        ("A", Date.valueOf("2026-01-15"), 10.0, 90),
        ("A", Date.valueOf("2026-01-16"), 10.0, 120),
        ("A", Date.valueOf("2026-01-17"), 5.0, 300),
        ("B", Date.valueOf("2026-01-15"), 100.0, 20),
        ("B", Date.valueOf("2026-01-16"), 100.0, 30),
        ("C", Date.valueOf("2026-01-17"), 80.0, 60),
        ("C", Date.valueOf("2026-01-18"), 82.0, 50)
    )
).toDF("product", "date", "price", "sales")

df.show()
// Out:
// +-------+----------+-----+-----+
// |product|      date|price|sales|
// +-------+----------+-----+-----+
// |      A|2026-01-15| 10.0|   90|
// |      A|2026-01-16| 10.0|  120|
// |      A|2026-01-17|  5.0|  300|
// |      B|2026-01-15|100.0|   20|
// |      B|2026-01-16|100.0|   30|
// |      C|2026-01-17| 80.0|   60|
// |      C|2026-01-18| 82.0|   50|
// +-------+----------+-----+-----+
// df: DataFrame = [product: string, date: date ... 2 more fields]

// %% [markdown]
// ## Add provenance column to the DataFrame
//
// The provenance column is added using the `addProvenanceColumn` method, which is provided by the `DataFrameProvenanceTransformations` trait.
//
// This method adds a new column to the DataFrame that contains the provenance information for each row. By default the provenance type is a uuid but can be customized by choosing a column name of the dataframe.
//
// By adding the provenance column, users can easily trace back the origin of each row and understand the transformations that were applied to it, which can be useful for debugging and analysing purposes.

// %%
val dfWithProv : DataFrame = df.addProvenanceColumn
dfWithProv.show(false)

val dfWithProv2 : DataFrame = df.addProvenanceColumn(col("product"))
dfWithProv2.show(false)
// Out:
// +-------+----------+-----+-----+------------------------------------+
// |product|date      |price|sales|_provenance_tag                     |
// +-------+----------+-----+-----+------------------------------------+
// |A      |2026-01-15|10.0 |90   |57d85808-9c54-4a0b-a116-7ded1f61d862|
// |A      |2026-01-16|10.0 |120  |f0b934f0-e3dd-4ce4-b3b6-77e741703874|
// |A      |2026-01-17|5.0  |300  |b0906b68-306a-4af3-8941-e159e1a33ae9|
// |B      |2026-01-15|100.0|20   |fa23fea0-53cf-44fc-833e-4303b9668b46|
// |B      |2026-01-16|100.0|30   |df602184-8df4-43f3-b46c-e85173e1e4f3|
// |C      |2026-01-17|80.0 |60   |e8a2778c-92ec-4279-af4b-7c6cf7f169f3|
// |C      |2026-01-18|82.0 |50   |85b30897-a86e-4eef-af7a-b27f79d866a4|
// +-------+----------+-----+-----+------------------------------------+
//
// +-------+----------+-----+-----+---------------+
// |product|date      |price|sales|_provenance_tag|
// +-------+----------+-----+-----+---------------+
// |A      |2026-01-15|10.0 |90   |A              |
// |A      |2026-01-16|10.0 |120  |A              |
// |A      |2026-01-17|5.0  |300  |A              |
// |B      |2026-01-15|100.0|20   |B              |
// |B      |2026-01-16|100.0|30   |B              |
// |C      |2026-01-17|80.0 |60   |C              |
// |C      |2026-01-18|82.0 |50   |C              |
// +-------+----------+-----+-----+---------------+
// dfWithProv: DataFrame = [product: string, date: date ... 3 more fields]
// dfWithProv2: DataFrame = [product: string, date: date ... 3 more fields]

// %% [markdown]
// ## Use the new DataFrame with provenance
//
// You can use the same SQL or DataFrame API as before, but now you have access to the provenance information for debugging and analysis purposes.
// You have nothing more to do, the provenance column will be calculated automatically.
//
// Example query: find products with price > 50 and sales < 50.

// %%
// SQL API with provenance
dfWithProv.createOrReplaceTempView("why_prov")
val resultWithProv = sparkWhy.sql(
    """
    SELECT product, date, price, sales
    FROM why_prov
    WHERE price > 50 AND sales < 50
    """
)
resultWithProv.show(false)

// DataFrame API with provenance
val resultWithProv2 = dfWithProv
    .filter(col("price") > 50 && col("sales") < 50)
    .select("product", "date", "price", "sales")
resultWithProv2.show(false)
// Out:
// +-------+----------+-----+-----+------------------------------------+
// |product|date      |price|sales|_provenance_tag                     |
// +-------+----------+-----+-----+------------------------------------+
// |B      |2026-01-15|100.0|20   |fa23fea0-53cf-44fc-833e-4303b9668b46|
// |B      |2026-01-16|100.0|30   |df602184-8df4-43f3-b46c-e85173e1e4f3|
// +-------+----------+-----+-----+------------------------------------+
//
// +-------+----------+-----+-----+------------------------------------+
// |product|date      |price|sales|_provenance_tag                     |
// +-------+----------+-----+-----+------------------------------------+
// |B      |2026-01-15|100.0|20   |fa23fea0-53cf-44fc-833e-4303b9668b46|
// |B      |2026-01-16|100.0|30   |df602184-8df4-43f3-b46c-e85173e1e4f3|
// +-------+----------+-----+-----+------------------------------------+
// resultWithProv: DataFrame = [product: string, date: date ... 3 more fields]
// resultWithProv2: DataFrame = [product: string, date: date ... 3 more fields]

// %% [markdown]
// ### Test join with provenance

// %%
// left : filter on price and sales, price > 50 AND sales < 50
val left = dfWithProv.select("product", "date", "price", "sales").filter(col("price") > 50 && col("sales") < 50)
// right : filter on date, date > 2026-01-15
val right = dfWithProv.select("product", "date", "price", "sales").filter(col("date") > Date.valueOf("2026-01-15"))
// join on product, inner join, 
val joined = left.join(right, Seq("product"), "inner")

// show all three
println("Left:")
left.show(false)

println("Right:")
right.show(false)

println("Joined:")
joined.show(false)
joined.printSchema()  // Show the schema of the joined DataFrame with provenance information
// Out:
// Left:
// +-------+----------+-----+-----+------------------------------------+
// |product|date      |price|sales|_provenance_tag                     |
// +-------+----------+-----+-----+------------------------------------+
// |B      |2026-01-15|100.0|20   |fa23fea0-53cf-44fc-833e-4303b9668b46|
// |B      |2026-01-16|100.0|30   |df602184-8df4-43f3-b46c-e85173e1e4f3|
// +-------+----------+-----+-----+------------------------------------+
//
// Right:
// +-------+----------+-----+-----+------------------------------------+
// |product|date      |price|sales|_provenance_tag                     |
// +-------+----------+-----+-----+------------------------------------+
// |A      |2026-01-16|10.0 |120  |f0b934f0-e3dd-4ce4-b3b6-77e741703874|
// |A      |2026-01-17|5.0  |300  |b0906b68-306a-4af3-8941-e159e1a33ae9|
// |B      |2026-01-16|100.0|30   |df602184-8df4-43f3-b46c-e85173e1e4f3|
// |C      |2026-01-17|80.0 |60   |e8a2778c-92ec-4279-af4b-7c6cf7f169f3|
// |C      |2026-01-18|82.0 |50   |85b30897-a86e-4eef-af7a-b27f79d866a4|
// +-------+----------+-----+-----+------------------------------------+
//
// Joined:
// +-------+----------+-----+-----+----------+-----+-----+----------------------------------------------------------------------------+
// |product|date      |price|sales|date      |price|sales|_provenance_tag                                                             |
// +-------+----------+-----+-----+----------+-----+-----+----------------------------------------------------------------------------+
// |B      |2026-01-16|100.0|30   |2026-01-16|100.0|30   |[df602184-8df4-43f3-b46c-e85173e1e4f3]                                      |
// |B      |2026-01-15|100.0|20   |2026-01-16|100.0|30   |[fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3]|
// +-------+----------+-----+-----+----------+-----+-----+----------------------------------------------------------------------------+
//
// root
//  |-- product: string (nullable = true)
//  |-- date: date (nullable = true)
//  |-- price: double (nullable = false)
//  |-- sales: integer (nullable = false)
//  |-- date: date (nullable = true)
//  |-- price: double (nullable = false)
//  |-- sales: integer (nullable = false)
//  |-- _provenance_tag: array (nullable = true)
//  |    |-- element: string (containsNull = true)
// left: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [product: string, date: date ... 3 more fields]
// right: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [product: string, date: date ... 3 more fields]
// joined: DataFrame = [product: string, date: date ... 6 more fields]

// %% [markdown]
// ### Test distinct with provenance

// %%
// Get distinct products from the joined result
// The provenance column will contain the provenance information
val distinctProducts = dfWithProv.select("product").distinct()
distinctProducts.show(false)
// Out:
// +-------+--------------------------------------+
// |product|_provenance_tag                       |
// +-------+--------------------------------------+
// |A      |[b0906b68-306a-4af3-8941-e159e1a33ae9]|
// |B      |[df602184-8df4-43f3-b46c-e85173e1e4f3]|
// |C      |[85b30897-a86e-4eef-af7a-b27f79d866a4]|
// +-------+--------------------------------------+
// distinctProducts: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [product: string, _provenance_tag: array<string>]

// %% [markdown]
// ### Test aggregations with provenance
//
// If the provenance column is not a uuid, the aggregation might not be as precise as expected, since the provenance information will not contain the full lineage of the aggregated rows.
//
// The provenance information will be based on the provenance of the rows that are aggregated, which may not be unique for each row.

// %%
val aggreg = dfWithProv.groupBy("product").agg(
    max("date").as("first_date"),
    min("date").as("last_date"),
    round(mean("price"), 2).as("average_price"),
    sum("sales").as("total_sales")
)
aggreg.show(false)

val aggreg2 = dfWithProv2.groupBy("product").agg(
    max("date").as("first_date"),
    min("date").as("last_date"),
    round(mean("price"), 2).as("average_price"),
    sum("sales").as("total_sales")
)
aggreg2.show(false)
// Out:
// +-------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------+
// |product|first_date|last_date |average_price|total_sales|_provenance_tag                                                                                                   |
// +-------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------+
// |A      |2026-01-17|2026-01-15|8.33         |510        |[57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9]|
// |B      |2026-01-16|2026-01-15|100.0        |50         |[fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3]                                      |
// |C      |2026-01-18|2026-01-17|81.0         |110        |[e8a2778c-92ec-4279-af4b-7c6cf7f169f3, 85b30897-a86e-4eef-af7a-b27f79d866a4]                                      |
// +-------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------+
//
// +-------+----------+----------+-------------+-----------+---------------+
// |product|first_date|last_date |average_price|total_sales|_provenance_tag|
// +-------+----------+----------+-------------+-----------+---------------+
// |A      |2026-01-17|2026-01-15|8.33         |510        |[A]            |
// |B      |2026-01-16|2026-01-15|100.0        |50         |[B]            |
// |C      |2026-01-18|2026-01-17|81.0         |110        |[C]            |
// +-------+----------+----------+-------------+-----------+---------------+
// aggreg: DataFrame = [product: string, first_date: date ... 4 more fields]
// aggreg2: DataFrame = [product: string, first_date: date ... 4 more fields]

// %% [markdown]
// ### Test window functions with provenance

// %%
val window2 = dfWithProv.select(
    col("product"), 
    col("date"), 
    col("price"), 
    col("sales"), 

    // avg(col("price")).over(partitionBy("product").orderBy("date").rowsBetween(currentRow -1, currentRow )).as("avg_price"),
    // avg(col("price")).over(partitionBy("product").orderBy("date").rowsBetween(currentRow , currentRow + 1)).as("avg_price"),
    // sum(col("sales")).over(partitionBy("product").orderBy("date")).as("total_sales")

    sum(col("sales")).over(partitionBy(
        min(col("date")).over(partitionBy("product"))
    )).as("sales_for_min_date")
)

window2.show(false)
// Out:
// +-------+----------+-----+-----+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// |product|date      |price|sales|sales_for_min_date|_provenance_tag                                                                                                                                                                                       |
// +-------+----------+-----+-----+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// |A      |2026-01-15|10.0 |90   |560               |ArraySeq(57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9, fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3)|
// |A      |2026-01-16|10.0 |120  |560               |ArraySeq(57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9, fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3)|
// |A      |2026-01-17|5.0  |300  |560               |ArraySeq(57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9, fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3)|
// |B      |2026-01-15|100.0|20   |560               |ArraySeq(57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9, fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3)|
// |B      |2026-01-16|100.0|30   |560               |ArraySeq(57d85808-9c54-4a0b-a116-7ded1f61d862, f0b934f0-e3dd-4ce4-b3b6-77e741703874, b0906b68-306a-4af3-8941-e159e1a33ae9, fa23fea0-53cf-44fc-833e-4303b9668b46, df602184-8df4-43f3-b46c-e85173e1e4f3)|
// |C      |2026-01-17|80.0 |60   |110               |ArraySeq(e8a2778c-92ec-4279-af4b-7c6cf7f169f3, 85b30897-a86e-4eef-af7a-b27f79d866a4)                                                                                                                  |
// |C      |2026-01-18|82.0 |50   |110               |ArraySeq(e8a2778c-92ec-4279-af4b-7c6cf7f169f3, 85b30897-a86e-4eef-af7a-b27f79d866a4)                                                                                                                  |
// +-------+----------+-----+-----+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
// window2: DataFrame = [product: string, date: date ... 4 more fields]
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
