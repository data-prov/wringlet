// %% [markdown]
// **Prerequisite to run this notebook:** having [almond jupyter plugin](https://almond.sh/) installed, and running cells using a Scala kernel

// %% [markdown]
// To use Spark, we can use `$ivy` magic: https://almond.sh/docs/usage-spark

// %%
import $ivy.`org.apache.spark::spark-sql:4.1.1`
// Out:
// import $ivy.$

// %% [markdown]
// We can also use `ivy` to load project source code from local Ivy/Maven cache (run `make publish-local` to update):

// %%
val version = scala.io.Source.fromFile("../VERSION")  // Get version from file
  .getLines().next().trim

interp.load.ivy("org.dataprov.dp" %% "dp-spark" % version)  // use porogrammatic API 

// // For publishLocal (~/.ivy2/local)
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method

// // For publishM2 (~/.m2)
// import $repo.`file:///home/ronan/.m2/repository`
// import $ivy.`org.dataprov.dp::dp-spark:0.0.1` // N.B: version must be specified explicitly with this method
// Out:
// version: String = "0.0.1"

// %% [markdown]
// Import libraries (Spark, dataprovenance project, ...):

// %%
import java.sql.Date

import org.apache.spark.sql.{SparkSession, DataFrame}
import org.apache.spark.sql.functions._
import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
import org.apache.spark.sql.execution.SparkPlan

import org.dataprov.dp.wringlet.DataFrameProvenanceTransformations._
// Out:
// import java.sql.Date
// import org.apache.spark.sql.{SparkSession, DataFrame}
// import org.apache.spark.sql.functions._
// import org.apache.spark.sql.catalyst.plans.logical.LogicalPlan
// import org.apache.spark.sql.execution.SparkPlan
// import org.dataprov.dp.wringlet.DataFrameProvenanceTransformations._

// %% [markdown]
// Initialize Spark session:

// %%
val spark = SparkSession.builder()
  .master("local[*]")
  .appName("notebook")
  .getOrCreate()
// Out:
// spark: SparkSession = org.apache.spark.sql.classic.SparkSession@d147928

// %% [markdown]
// Create Spark dataframe:

// %%
val df: DataFrame = spark.createDataFrame(
    Seq(
        ("A", Date.valueOf("2026-01-15"), 10.0, 90),
        ("A", Date.valueOf("2026-01-16"), 10.0, 120),
        ("A", Date.valueOf("2026-01-17"), 5.0, 300),
        ("B", Date.valueOf("2026-01-15"), 100.0, 20),
        ("B", Date.valueOf("2026-01-16"), 100.0, 30),
        ("B", Date.valueOf("2026-01-17"), 80.0, 60)
    )
).toDF("product", "date", "price", "sales")

df.show()
// Out:
// +-------+----------+-----+-----+
// |product|      date|price|sales|
// +-------+----------+-----+-----+
// |      A|2026-01-15| 10.0|   90|
// |      A|2026-01-16| 10.0|  120|
// |      A|2026-01-17|  5.0|  300|
// |      B|2026-01-15|100.0|   20|
// |      B|2026-01-16|100.0|   30|
// |      B|2026-01-17| 80.0|   60|
// +-------+----------+-----+-----+
// df: DataFrame = [product: string, date: date ... 2 more fields]

// %% [markdown]
// Apply provenance:
// (Note that because we imported implicit class `org.dataprov.dp.wringlet.DataFrameProvenanceTransformations.DataFrameWithProvenance`, all Spark `DataFrame` are automatically *"monkey patched"* to `DataFrameWithProvenance`, see [Implicit Class in Scala](https://docs.scala-lang.org/overviews/core/implicit-classes.html) )

// %%
df.addProvenanceColumn.show()
// Out:
// +-------+----------+-----+-----+---------------+
// |product|      date|price|sales|_provenance_tag|
// +-------+----------+-----+-----+---------------+
// |      A|2026-01-15| 10.0|   90|              0|
// |      A|2026-01-16| 10.0|  120|              1|
// |      A|2026-01-17|  5.0|  300|              2|
// |      B|2026-01-15|100.0|   20|              3|
// |      B|2026-01-16|100.0|   30|              4|
// |      B|2026-01-17| 80.0|   60|              5|
// +-------+----------+-----+-----+---------------+

// %% [markdown]
// Get logical + physical plans:

// %%
val df2 = df.groupBy("product")
  .agg(
    sum("sales").as("total_sales"),
    avg("price").as("avg_price")
  )
df2.show()

df.explain(true)  // print logical plans

// 1. Parsed Logical Plan (Unresolved)
val parsedPlan: LogicalPlan = df.queryExecution.logical

// 2. Analyzed Logical Plan (Resolved)
// This is usually what you want when inspecting the schema and resolved columns
val analyzedPlan: LogicalPlan = df.queryExecution.analyzed

// 3. Optimized Logical Plan
// This is the plan after Spark's Catalyst optimizer has applied its rules
val optimizedPlan: LogicalPlan = df.queryExecution.optimizedPlan

// 4. Physical Plan
// This is the plan produced by the physical planning strategies, 
// but BEFORE rule-based physical optimizations (like whole-stage codegen) are applied.
val physicalPlan: SparkPlan = df.queryExecution.sparkPlan

// 5. Executed Physical Plan (Final)
// This is the absolute final plan that Spark actually runs. It includes 
// execution-specific preparations like adding Exchange nodes (shuffles) 
// and WholeStageCodegen blocks.
val executedPlan: SparkPlan = df.queryExecution.executedPlan
// Out:
// 26/05/01 00:28:25 INFO DAGScheduler: Registering RDD 50 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) as input to shuffle 8
// 26/05/01 00:28:25 INFO DAGScheduler: Got map stage job 16 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) with 6 output partitions
// 26/05/01 00:28:25 INFO DAGScheduler: Final stage: ShuffleMapStage 24 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768)
// 26/05/01 00:28:25 INFO DAGScheduler: Parents of final stage: List()
// 26/05/01 00:28:25 INFO DAGScheduler: Missing parents: List()
// 26/05/01 00:28:25 INFO DAGScheduler: Missing parents found for ShuffleMapStage 24: List()
// 26/05/01 00:28:25 INFO DAGScheduler: Submitting ShuffleMapStage 24 (MapPartitionsRDD[50] at $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768), which has no missing parents
// 26/05/01 00:28:25 INFO MemoryStore: Block broadcast_16 stored as values in memory (estimated size 35.5 KiB, free 2.1 GiB)
// 26/05/01 00:28:25 INFO MemoryStore: Block broadcast_16_piece0 stored as bytes in memory (estimated size 15.5 KiB, free 2.1 GiB)
// 26/05/01 00:28:25 INFO SparkContext: Created broadcast 16 from broadcast at DAGScheduler.scala:1686
// 26/05/01 00:28:25 INFO DAGScheduler: Submitting 6 missing tasks from ShuffleMapStage 24 (MapPartitionsRDD[50] at $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) (first 15 tasks are for partitions Vector(0, 1, 2, 3, 4, 5))
// 26/05/01 00:28:25 INFO TaskSchedulerImpl: Adding task set 24.0 with 6 tasks resource profile 0
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 0.0 in stage 24.0 (TID 56) (10.255.255.254,executor driver, partition 0, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 1.0 in stage 24.0 (TID 57) (10.255.255.254,executor driver, partition 1, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 2.0 in stage 24.0 (TID 58) (10.255.255.254,executor driver, partition 2, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 3.0 in stage 24.0 (TID 59) (10.255.255.254,executor driver, partition 3, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 4.0 in stage 24.0 (TID 60) (10.255.255.254,executor driver, partition 4, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO TaskSetManager: Starting task 5.0 in stage 24.0 (TID 61) (10.255.255.254,executor driver, partition 5, PROCESS_LOCAL, 10098 bytes)
// 26/05/01 00:28:25 INFO Executor: Running task 1.0 in stage 24.0 (TID 57)
// 26/05/01 00:28:25 INFO Executor: Running task 3.0 in stage 24.0 (TID 59)
// 26/05/01 00:28:25 INFO Executor: Running task 2.0 in stage 24.0 (TID 58)
// 26/05/01 00:28:25 INFO Executor: Running task 4.0 in stage 24.0 (TID 60)
// 26/05/01 00:28:25 INFO Executor: Running task 0.0 in stage 24.0 (TID 56)
// 26/05/01 00:28:25 INFO Executor: Running task 5.0 in stage 24.0 (TID 61)
// 26/05/01 00:28:25 INFO Executor: Finished task 4.0 in stage 24.0 (TID 60). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO Executor: Finished task 2.0 in stage 24.0 (TID 58). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 4.0 in stage 24.0 (TID 60) in 14 ms on 10.255.255.254 (executor driver) (1/6)
// 26/05/01 00:28:25 INFO Executor: Finished task 5.0 in stage 24.0 (TID 61). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 2.0 in stage 24.0 (TID 58) in 15 ms on 10.255.255.254 (executor driver) (2/6)
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 5.0 in stage 24.0 (TID 61) in 14 ms on 10.255.255.254 (executor driver) (3/6)
// 26/05/01 00:28:25 INFO Executor: Finished task 0.0 in stage 24.0 (TID 56). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO Executor: Finished task 3.0 in stage 24.0 (TID 59). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO Executor: Finished task 1.0 in stage 24.0 (TID 57). 2454 bytes result sent to driver
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 3.0 in stage 24.0 (TID 59) in 17 ms on 10.255.255.254 (executor driver) (4/6)
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 0.0 in stage 24.0 (TID 56) in 20 ms on 10.255.255.254 (executor driver) (5/6)
// 26/05/01 00:28:25 INFO TaskSetManager: Finished task 1.0 in stage 24.0 (TID 57) in 19 ms on 10.255.255.254 (executor driver) (6/6)
// 26/05/01 00:28:25 INFO TaskSchedulerImpl: Removed TaskSet 24.0 whose tasks have all completed, from pool
// 26/05/01 00:28:25 INFO DAGScheduler: ShuffleMapStage 24 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) finished in 25 ms
// 26/05/01 00:28:25 INFO DAGScheduler: looking for newly runnable stages
// 26/05/01 00:28:25 INFO DAGScheduler: running: HashSet()
// 26/05/01 00:28:25 INFO DAGScheduler: waiting: HashSet()
// 26/05/01 00:28:25 INFO DAGScheduler: failed: HashSet()
// 26/05/01 00:28:25 INFO ShufflePartitionsUtil: For shuffle(8, advisory target size: 67108864, actual target size 1048576, minimum partition size: 1048576
// 26/05/01 00:28:25 INFO HashAggregateExec: spark.sql.codegen.aggregate.map.twolevel.enabled is set to true, but current version of codegened fast hashmap does not support this aggregate.
// 26/05/01 00:28:26 INFO SparkContext: Starting job: $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768
// 26/05/01 00:28:26 INFO DAGScheduler: Got job 17 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) with 1 output partitions
// 26/05/01 00:28:26 INFO DAGScheduler: Final stage: ResultStage 26 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768)
// 26/05/01 00:28:26 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 25)
// 26/05/01 00:28:26 INFO DAGScheduler: Missing parents: List()
// 26/05/01 00:28:26 INFO DAGScheduler: Missing parents found for ResultStage 26: List()
// 26/05/01 00:28:26 INFO DAGScheduler: Submitting ResultStage 26 (MapPartitionsRDD[53] at $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768), which has no missing parents
// 26/05/01 00:28:26 INFO MemoryStore: Block broadcast_17 stored as values in memory (estimated size 43.2 KiB, free 2.1 GiB)
// 26/05/01 00:28:26 INFO MemoryStore: Block broadcast_17_piece0 stored as bytes in memory (estimated size 18.2 KiB, free 2.1 GiB)
// 26/05/01 00:28:26 INFO SparkContext: Created broadcast 17 from broadcast at DAGScheduler.scala:1686
// 26/05/01 00:28:26 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 26 (MapPartitionsRDD[53] at $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) (first 15 tasks are for partitions Vector(0))
// 26/05/01 00:28:26 INFO TaskSchedulerImpl: Adding task set 26.0 with 1 tasks resource profile 0
// 26/05/01 00:28:26 INFO TaskSetManager: Starting task 0.0 in stage 26.0 (TID 62) (10.255.255.254,executor driver, partition 0, NODE_LOCAL, 9849 bytes)
// 26/05/01 00:28:26 INFO Executor: Running task 0.0 in stage 26.0 (TID 62)
// 26/05/01 00:28:26 INFO ShuffleBlockFetcherIterator: Getting 6 (520.0 B) non-empty blocks including 6 (520.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
// 26/05/01 00:28:26 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 0 ms
// 26/05/01 00:28:26 INFO Executor: Finished task 0.0 in stage 26.0 (TID 62). 4789 bytes result sent to driver
// 26/05/01 00:28:26 INFO TaskSetManager: Finished task 0.0 in stage 26.0 (TID 62) in 15 ms on 10.255.255.254 (executor driver) (1/1)
// 26/05/01 00:28:26 INFO TaskSchedulerImpl: Removed TaskSet 26.0 whose tasks have all completed, from pool
// 26/05/01 00:28:26 INFO DAGScheduler: ResultStage 26 ($anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768) finished in 22 ms
// 26/05/01 00:28:26 INFO DAGScheduler: Job 17 is finished. Cancelling potential speculative or zombie tasks for this job
// 26/05/01 00:28:26 INFO TaskSchedulerImpl: Canceling stage 26
// 26/05/01 00:28:26 INFO TaskSchedulerImpl: Killing all running tasks in stage 26: Stage finished
// 26/05/01 00:28:26 INFO DAGScheduler: Job 17 finished: $anonfun$withThreadLocalCaptured$2 at CompletableFuture.java:1768, took 26.427203 ms
// +-------+-----------+-----------------+
// |product|total_sales|        avg_price|
// +-------+-----------+-----------------+
// |      A|        510|8.333333333333334|
// |      B|        110|93.33333333333333|
// +-------+-----------+-----------------+
//
// == Parsed Logical Plan ==
// 'UnresolvedSubqueryColumnAliases [product, date, price, sales]
// +- LocalRelation [_1#173, _2#174, _3#175, _4#176]
//
// == Analyzed Logical Plan ==
// product: string, date: date, price: double, sales: int
// Project [_1#173 AS product#177, _2#174 AS date#178, _3#175 AS price#179, _4#176 AS sales#180]
// +- LocalRelation [_1#173, _2#174, _3#175, _4#176]
//
// == Optimized Logical Plan ==
// LocalRelation [product#177, date#178, price#179, sales#180]
//
// == Physical Plan ==
// LocalTableScan [product#177, date#178, price#179, sales#180]
// df2: DataFrame = [product: string, total_sales: bigint ... 1 more field]
// parsedPlan: LogicalPlan = UnresolvedSubqueryColumnAliases(
//   outputColumnNames = ArraySeq("product", "date", "price", "sales"),
//   child = LocalRelation(
//     output = List(
//       AttributeReference(
//         name = "_1",
//         dataType = StringType,
//         nullable = true,
//         metadata = {}
//       ),
//       AttributeReference(
//         name = "_2",
//         dataType = DateType,
//         nullable = true,
//         metadata = {}
//       ),
//       AttributeReference(
//         name = "_3",
//         dataType = DoubleType,
//         nullable = false,
//         metadata = {}
//       ),
//       AttributeReference(
//         name = "_4",
//         dataType = IntegerType,
//         nullable = false,
//         metadata = {}
//       )
//     ),
//     data = List(
//       [A,20468,10.0,90],
//       [A,20469,10.0,120],
//       [A,20470,5.0,300],
//       [B,20468,100.0,20],
//       [B,20469,100.0,30],
//       [B,20470,80.0,60]
//     ),
//     isStreaming = false,
//     stream = None
// ...
// analyzedPlan: LogicalPlan = Project(
//   projectList = List(
//     Alias(
//       child = AttributeReference(
//         name = "_1",
//         dataType = StringType,
//         nullable = true,
//         metadata = {}
//       ),
//       name = "product"
//     ),
//     Alias(
//       child = AttributeReference(
//         name = "_2",
//         dataType = DateType,
//         nullable = true,
//         metadata = {}
//       ),
//       name = "date"
//     ),
//     Alias(
//       child = AttributeReference(
//         name = "_3",
//         dataType = DoubleType,
//         nullable = false,
//         metadata = {}
//       ),
//       name = "price"
//     ),
//     Alias(
//       child = AttributeReference(
//         name = "_4",
//         dataType = IntegerType,
//         nullable = false,
//         metadata = {}
//       ),
//       name = "sales"
//     )
//   ),
// ...
// optimizedPlan: LogicalPlan = LocalRelation(
//   output = List(
//     AttributeReference(
//       name = "product",
//       dataType = StringType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "date",
//       dataType = DateType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "price",
//       dataType = DoubleType,
//       nullable = false,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "sales",
//       dataType = IntegerType,
//       nullable = false,
//       metadata = {}
//     )
//   ),
//   data = List(
//     [A,20468,10.0,90],
//     [A,20469,10.0,120],
//     [A,20470,5.0,300],
//     [B,20468,100.0,20],
//     [B,20469,100.0,30],
//     [B,20470,80.0,60]
//   ),
//   isStreaming = false,
//   stream = None
// )
// physicalPlan: SparkPlan = LocalTableScanExec(
//   output = List(
//     AttributeReference(
//       name = "product",
//       dataType = StringType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "date",
//       dataType = DateType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "price",
//       dataType = DoubleType,
//       nullable = false,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "sales",
//       dataType = IntegerType,
//       nullable = false,
//       metadata = {}
//     )
//   ),
//   rows = List(
//     [A,20468,10.0,90],
//     [A,20469,10.0,120],
//     [A,20470,5.0,300],
//     [B,20468,100.0,20],
//     [B,20469,100.0,30],
//     [B,20470,80.0,60]
//   ),
//   stream = None
// )
// executedPlan: SparkPlan = LocalTableScanExec(
//   output = List(
//     AttributeReference(
//       name = "product",
//       dataType = StringType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "date",
//       dataType = DateType,
//       nullable = true,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "price",
//       dataType = DoubleType,
//       nullable = false,
//       metadata = {}
//     ),
//     AttributeReference(
//       name = "sales",
//       dataType = IntegerType,
//       nullable = false,
//       metadata = {}
//     )
//   ),
//   rows = List(
//     [A,20468,10.0,90],
//     [A,20469,10.0,120],
//     [A,20470,5.0,300],
//     [B,20468,100.0,20],
//     [B,20469,100.0,30],
//     [B,20470,80.0,60]
//   ),
//   stream = None
// )
